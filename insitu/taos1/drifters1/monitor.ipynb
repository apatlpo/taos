# %% [markdown]
# # TAOS drifter deployments: monitoring
#
# [PacificGyre website](https://www.pacificgyre.com)

# %%
import taos.insitu as ins

# %% [markdown]
# ---
# ## manual downloading and position report

# %%
# fetch data from website
ins.fetch_drifter_data()
# Out:
#  Drifter data downloaded as drifter_data_20221130_155726.csv
# 'drifter_data_20221130_155726.csv'

# %%
# load all data
dr = ins.load_drifter_data()
# extrapolate to now
dr_now = ins.extrapolate(dr)

# %%
zoom = [-.4, -.1, 49.27, 49.4]
zoom = [-.5, -.1, 49.27, 49.45]
ins.show_last_positions(dr, dr_now, zoom=zoom, offset="2h")
# Out:
#  drifter 0-4352044: -0.0W 15.197  49.0N 20.567  speed=(-0.28, 0.08) at 2022/11/30 15:54:52
#  drifter 0-4350125: -0.0W 15.200  49.0N 20.567  speed=(-0.28, 0.09) at 2022/11/30 15:55:06
#  drifter 0-4351896: -0.0W 15.095  49.0N 20.529  speed=(-0.08, -0.01) at 2022/11/30 15:55:01
#  drifter 0-4350124: 1.0E 17.770  50.0N 31.522  speed=(0.31, 0.60) at 2022/11/30 15:52:43

# %% [markdown]
# ---
# ### automatic monitoring

# %%
#%matplotlib inline

# %%
#ins.monitor_drifters(refresh_time=5/60)
