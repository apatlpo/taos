# %% [markdown]
# # TAOS drifter deployments: monitoring
#
# [PacificGyre website](https://www.pacificgyre.com)

# %%
import taos.insitu as ins

# %% [markdown]
# ---
# ## manual downloading and position report

# %%
# fetch data from website
ins.fetch_drifter_data()
# Out:
#  Drifter data downloaded as drifter_data_20220518_183122.csv
# 'drifter_data_20220518_183122.csv'

# %%
# load all data
dr = ins.load_drifter_data()
# extrapolate to now
dr_now = ins.extrapolate(dr)

# %%
zoom = [-.4, -.1, 49.27, 49.4]
zoom = [-.5, -.1, 49.27, 49.45]
ins.show_last_positions(dr, dr_now, zoom=zoom, offset="2h")
# Out:
#  drifter 0-4352044: -0.0W 25.393  49.0N 23.346  speed=(-0.24, -0.11) at 2022/05/18 18:28:32
#  drifter 0-4352175: -0.0W 24.114  49.0N 24.704  speed=(-0.37, -0.17) at 2022/05/18 18:28:37
#  drifter 0-4351908: -0.0W 24.338  49.0N 24.809  speed=(-0.37, -0.18) at 2022/05/18 18:26:52
#  drifter 0-4352049: -0.0W 23.912  49.0N 24.614  speed=(-0.25, 0.07) at 2022/05/18 18:27:21
#  drifter 0-4351896: -0.0W 24.068  49.0N 24.468  speed=(-0.16, 0.10) at 2022/05/18 18:27:22
#  drifter 0-4351904: -0.0W 23.849  49.0N 24.670  speed=(-0.26, 0.07) at 2022/05/18 18:29:38

# %% [markdown]
# ---
# ### automatic monitoring

# %%
#%matplotlib inline

# %%
#ins.monitor_drifters(refresh_time=5/60)
