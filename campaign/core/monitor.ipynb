# %% [markdown]
# # TAOS drifter deployments: monitoring
#
# [PacificGyre website](https://www.pacificgyre.com)

# %%
import taos.insitu as ins

# %% [markdown]
# ---
# ## manual downloading and position report

# %%
# fetch data from website
ins.fetch_drifter_data()
# Out:
#  Drifter data downloaded as drifter_data_20221114_111954.csv
# 'drifter_data_20221114_111954.csv'

# %%
# load all data
dr = ins.load_drifter_data()
# extrapolate to now
dr_now = ins.extrapolate(dr)

# %%
zoom = [-.4, -.1, 49.27, 49.4]
zoom = [-.5, -.1, 49.27, 49.45]
ins.show_last_positions(dr, dr_now, zoom=zoom, offset="2h")
# Out:
#  drifter 0-4352185: -0.0W 14.435  49.0N 20.326  speed=(0.33, -0.09) at 2022/11/14 11:16:31
#  drifter 0-4352181: -0.0W 14.584  49.0N 20.399  speed=(0.11, 0.00) at 2022/11/14 11:16:29
#  drifter 0-4350124: -0.0W 14.599  49.0N 20.394  speed=(0.09, -0.01) at 2022/11/14 11:15:24
#  drifter 0-4350125: -0.0W 45.171  49.0N 20.417  speed=(0.05, 0.14) at 2022/11/14 06:09:37

# %% [markdown]
# ---
# ### automatic monitoring

# %%
#%matplotlib inline

# %%
#ins.monitor_drifters(refresh_time=5/60)
